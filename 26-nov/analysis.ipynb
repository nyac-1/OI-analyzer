# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime
from datetime import datetime
import pickle5 as pickle
import os
import json

# %%
def get_change(history):
    data = list()
    
    for i in range(1,len(history)):
        delta = float(((datetime.strptime(history[i]['time'], '%H:%M:%S') - datetime.strptime(history[i-1]['time'], '%H:%M:%S')).seconds)/60)
        ce_normaldiff = float((history[i]['CE_CHOI'] - history[i-1]['CE_CHOI'])/delta)
        pe_normaldiff = float((history[i]['PE_CHOI'] - history[i-1]['PE_CHOI'])/delta)
        
        try:
            pcr = float(pe_normaldiff/ce_normaldiff)
        except:
            pcr = np.nan
        dic = {
            "ce_normaldiff": ce_normaldiff,
            "pe_normaldiff": pe_normaldiff,
            "pcr_in_window": pcr,
            "nifty_start": history[i-1]['nifty'],
            "nifty_end": history[i]['nifty'],
            "start_time": history[i-1]['time'],
            "end_time": history[i]['time']
        }
        
        data.append(dic)
    return data

# %%
with open("test.txt", "rb") as fp:
    history = pickle.load(fp)
history
# Out:
# [{'CE_CHOI': 0.0,
#   'PE_CHOI': 0.0,
#   'CE_OI': 16852500.0,
#   'PE_OI': 17424075.0,
#   'ce_ratio': 0.0,
#   'pe_ratio': 0.0,
#   'pe_ce_choi_diff': 0.0,
#   'nifty': 12894,
#   'time': '09:15:49'},
#  {'CE_CHOI': 422550.0,
#   'PE_CHOI': -6000.0,
#   'CE_OI': 18597450.0,
#   'PE_OI': 15054900.0,
#   'ce_ratio': 0.02272085689167063,
#   'pe_ratio': -0.0003985413387003567,
#   'pe_ce_choi_diff': -428550.0,
#   'nifty': 12909,
#   'time': '09:18:19'},
#  {'CE_CHOI': 3092400.0,
#   'PE_CHOI': 2754900.0,
#   'CE_OI': 19944900.0,
#   'PE_OI': 20178975.0,
#   'ce_ratio': 0.15504715491178195,
#   'pe_ratio': 0.13652328723337037,
#   'pe_ce_choi_diff': -337500.0,
#   'nifty': 12859,
#   'time': '09:21:49'},
#  {'CE_CHOI': 4881075.0,
#   'PE_CHOI': 3929175.0,
#   'CE_OI': 21733575.0,
#   'PE_OI': 21353250.0,
#   'ce_ratio': 0.22458684316777153,
#   'pe_ratio': 0.18400828913631415,
#   'pe_ce_choi_diff': -951900.0,
#   'nifty': 12866,
#   'time': '09:23:20'},
#  {'CE_CHOI': 6760575.0,
#   'PE_CHOI': 5378700.0,
#   'CE_OI': 23613075.0,
#   'PE_OI': 22802775.0,
#   'ce_ratio': 0.28630642133648415,
#   'pe_ratio': 0.23587918575699668,
#   'pe_ce_choi_diff': -1381875.0,
#   'nifty': 12866,
#   'time': '09:27:50'},
#  {'CE_CHOI': 7561275.0,
#   'PE_CHOI': 6150900.0,
#   'CE_OI': 24413775.0,
#   'PE_OI': 23574975.0,
#   'ce_ratio': 0.3097134711858367,
#   'pe_ratio': 0.2609080179300296,
#   'pe_ce_choi_diff': -1410375.0,
#   'nifty': 12891,
#   'time': '09:30:50'},
#  {'CE_CHOI': 8050575.0,
#   'PE_CHOI': 5469825.0,
#   'CE_OI': 26225475.0,
#   'PE_OI': 20530725.0,
#   'ce_ratio': 0.3069753741352635,
#   'pe_ratio': 0.26642142447478107,
#   'pe_ce_choi_diff': -2580750.0,
#   'nifty': 12901,
#   'time': '09:32:20'},
#  {'CE_CHOI': 8572875.0,
#   'PE_CHOI': 7592925.0,
#   'CE_OI': 25425375.0,
#   'PE_OI': 25017000.0,
#   'ce_ratio': 0.33717791772982697,
#   'pe_ratio': 0.3035106127833074,
#   'pe_ce_choi_diff': -979950.0,
#   'nifty': 12886,
#   'time': '09:35:50'},
#  {'CE_CHOI': 9159900.0,
#   'PE_CHOI': 8023950.0,
#   'CE_OI': 26012400.0,
#   'PE_OI': 25448025.0,
#   'ce_ratio': 0.35213590441481757,
#   'pe_ratio': 0.3153073765056424,
#   'pe_ce_choi_diff': -1135950.0,
#   'nifty': 12862,
#   'time': '09:39:50'},
#  {'CE_CHOI': 7894875.0,
#   'PE_CHOI': 8172075.0,
#   'CE_OI': 21015825.0,
#   'PE_OI': 25545375.0,
#   'ce_ratio': 0.3756633394120859,
#   'pe_ratio': 0.31990428795819204,
#   'pe_ce_choi_diff': 277200.0,
#   'nifty': 12843,
#   'time': '09:43:20'},
#  {'CE_CHOI': 8822175.0,
#   'PE_CHOI': 7852650.0,
#   'CE_OI': 21943125.0,
#   'PE_OI': 25225950.0,
#   'ce_ratio': 0.40204733828932754,
#   'pe_ratio': 0.3112925380411838,
#   'pe_ce_choi_diff': -969525.0,
#   'nifty': 12829,
#   'time': '09:46:50'},
#  {'CE_CHOI': 9555150.0,
#   'PE_CHOI': 7733025.0,
#   'CE_OI': 22676100.0,
#   'PE_OI': 25106325.0,
#   'ce_ratio': 0.4213753687803458,
#   'pe_ratio': 0.30801102909326633,
#   'pe_ce_choi_diff': -1822125.0,
#   'nifty': 12816,
#   'time': '09:50:20'},
#  {'CE_CHOI': 11116275.0,
#   'PE_CHOI': 7945575.0,
#   'CE_OI': 24237225.0,
#   'PE_OI': 25318875.0,
#   'ce_ratio': 0.45864470870737056,
#   'pe_ratio': 0.3138202230549343,
#   'pe_ce_choi_diff': -3170700.0,
#   'nifty': 12827,
#   'time': '09:54:20'},
#  {'CE_CHOI': 11581950.0,
#   'PE_CHOI': 8002275.0,
#   'CE_OI': 24702900.0,
#   'PE_OI': 25375575.0,
#   'ce_ratio': 0.46884981115577523,
#   'pe_ratio': 0.31535344519286757,
#   'pe_ce_choi_diff': -3579675.0,
#   'nifty': 12842,
#   'time': '09:57:20'},
#  {'CE_CHOI': 13003950.0,
#   'PE_CHOI': 7690800.0,
#   'CE_OI': 26124900.0,
#   'PE_OI': 25064100.0,
#   'ce_ratio': 0.4977607569789741,
#   'pe_ratio': 0.30684524878212266,
#   'pe_ce_choi_diff': -5313150.0,
#   'nifty': 12818,
#   'time': '10:06:51'},
#  {'CE_CHOI': 13461150.0,
#   'PE_CHOI': 8014200.0,
#   'CE_OI': 26582100.0,
#   'PE_OI': 25387500.0,
#   'ce_ratio': 0.5063990429650027,
#   'pe_ratio': 0.3156750369276219,
#   'pe_ce_choi_diff': -5446950.0,
#   'nifty': 12816,
#   'time': '10:08:21'},
#  {'CE_CHOI': 16988775.0,
#   'PE_CHOI': 8580900.0,
#   'CE_OI': 33841275.0,
#   'PE_OI': 26004975.0,
#   'ce_ratio': 0.502013443642416,
#   'pe_ratio': 0.3299714766116868,
#   'pe_ce_choi_diff': -8407875.0,
#   'nifty': 12851,
#   'time': '10:18:21'},
#  {'CE_CHOI': 14163150.0,
#   'PE_CHOI': 9111150.0,
#   'CE_OI': 27284100.0,
#   'PE_OI': 26484450.0,
#   'ce_ratio': 0.5190990357021122,
#   'pe_ratio': 0.3440188487961804,
#   'pe_ce_choi_diff': -5052000.0,
#   'nifty': 12844,
#   'time': '10:22:21'},
#  {'CE_CHOI': 14357850.0,
#   'PE_CHOI': 9465825.0,
#   'CE_OI': 27478800.0,
#   'PE_OI': 26839125.0,
#   'ce_ratio': 0.5225064413293157,
#   'pe_ratio': 0.3526875410431599,
#   'pe_ce_choi_diff': -4892025.0,
#   'nifty': 12838,
#   'time': '10:25:51'},
#  {'CE_CHOI': 15296325.0,
#   'PE_CHOI': 9639450.0,
#   'CE_OI': 28417275.0,
#   'PE_OI': 27012750.0,
#   'ce_ratio': 0.5382755735727651,
#   'pe_ratio': 0.3568481550378988,
#   'pe_ce_choi_diff': -5656875.0,
#   'nifty': 12832,
#   'time': '10:34:21'},
#  {'CE_CHOI': 15580575.0,
#   'PE_CHOI': 9903375.0,
#   'CE_OI': 28701525.0,
#   'PE_OI': 27276675.0,
#   'ce_ratio': 0.5428483329718543,
#   'pe_ratio': 0.3630711954444594,
#   'pe_ce_choi_diff': -5677200.0,
#   'nifty': 12844,
#   'time': '10:39:51'},
#  {'CE_CHOI': 17022825.0,
#   'PE_CHOI': 11411250.0,
#   'CE_OI': 30143775.0,
#   'PE_OI': 28784550.0,
#   'ce_ratio': 0.564721074251649,
#   'pe_ratio': 0.39643663006717145,
#   'pe_ce_choi_diff': -5611575.0,
#   'nifty': 12845,
#   'time': '11:03:52'},
#  {'CE_CHOI': 18832800.0,
#   'PE_CHOI': 12723150.0,
#   'CE_OI': 31953750.0,
#   'PE_OI': 30096450.0,
#   'ce_ratio': 0.5893768337049642,
#   'pe_ratio': 0.42274587202145103,
#   'pe_ce_choi_diff': -6109650.0,
#   'nifty': 12832,
#   'time': '11:38:53'},
#  {'CE_CHOI': 19725825.0,
#   'PE_CHOI': 11853750.0,
#   'CE_OI': 32846775.0,
#   'PE_OI': 29227050.0,
#   'ce_ratio': 0.6005406923510755,
#   'pe_ratio': 0.40557463035099334,
#   'pe_ce_choi_diff': -7872075.0,
#   'nifty': 12819,
#   'time': '11:54:23'}]

# %%
get_change(history)
# Out:
# [{'ce_normaldiff': 169020.0,
#   'pe_normaldiff': -2400.0,
#   'pcr_in_window': -0.014199503017394392,
#   'nifty_start': 12894,
#   'nifty_end': 12909,
#   'start_time': '09:15:49',
#   'end_time': '09:18:19'},
#  {'ce_normaldiff': 762814.2857142857,
#   'pe_normaldiff': 788828.5714285715,
#   'pcr_in_window': 1.034103039496601,
#   'nifty_start': 12909,
#   'nifty_end': 12859,
#   'start_time': '09:18:19',
#   'end_time': '09:21:49'},
#  {'ce_normaldiff': 1179346.153846154,
#   'pe_normaldiff': 774247.2527472528,
#   'pcr_in_window': 0.6565055138580234,
#   'nifty_start': 12859,
#   'nifty_end': 12866,
#   'start_time': '09:21:49',
#   'end_time': '09:23:20'},
#  {'ce_normaldiff': 417666.6666666667,
#   'pe_normaldiff': 322116.6666666667,
#   'pcr_in_window': 0.7712290502793296,
#   'nifty_start': 12866,
#   'nifty_end': 12866,
#   'start_time': '09:23:20',
#   'end_time': '09:27:50'},
#  {'ce_normaldiff': 266900.0,
#   'pe_normaldiff': 257400.0,
#   'pcr_in_window': 0.9644061446234545,
#   'nifty_start': 12866,
#   'nifty_end': 12891,
#   'start_time': '09:27:50',
#   'end_time': '09:30:50'},
#  {'ce_normaldiff': 326200.0,
#   'pe_normaldiff': -454050.0,
#   'pcr_in_window': -1.391937461679951,
#   'nifty_start': 12891,
#   'nifty_end': 12901,
#   'start_time': '09:30:50',
#   'end_time': '09:32:20'},
#  {'ce_normaldiff': 149228.57142857142,
#   'pe_normaldiff': 606600.0,
#   'pcr_in_window': 4.064905226881103,
#   'nifty_start': 12901,
#   'nifty_end': 12886,
#   'start_time': '09:32:20',
#   'end_time': '09:35:50'},
#  {'ce_normaldiff': 146756.25,
#   'pe_normaldiff': 107756.25,
#   'pcr_in_window': 0.7342532260125207,
#   'nifty_start': 12886,
#   'nifty_end': 12862,
#   'start_time': '09:35:50',
#   'end_time': '09:39:50'},
#  {'ce_normaldiff': -361435.71428571426,
#   'pe_normaldiff': 42321.42857142857,
#   'pcr_in_window': -0.11709254757811112,
#   'nifty_start': 12862,
#   'nifty_end': 12843,
#   'start_time': '09:39:50',
#   'end_time': '09:43:20'},
#  {'ce_normaldiff': 264942.85714285716,
#   'pe_normaldiff': -91264.28571428571,
#   'pcr_in_window': -0.34446780977030084,
#   'nifty_start': 12843,
#   'nifty_end': 12829,
#   'start_time': '09:43:20',
#   'end_time': '09:46:50'},
#  {'ce_normaldiff': 209421.42857142858,
#   'pe_normaldiff': -34178.57142857143,
#   'pcr_in_window': -0.1632047477744807,
#   'nifty_start': 12829,
#   'nifty_end': 12816,
#   'start_time': '09:46:50',
#   'end_time': '09:50:20'},
#  {'ce_normaldiff': 390281.25,
#   'pe_normaldiff': 53137.5,
#   'pcr_in_window': 0.13615181359596445,
#   'nifty_start': 12816,
#   'nifty_end': 12827,
#   'start_time': '09:50:20',
#   'end_time': '09:54:20'},
#  {'ce_normaldiff': 155225.0,
#   'pe_normaldiff': 18900.0,
#   'pcr_in_window': 0.12175873731679819,
#   'nifty_start': 12827,
#   'nifty_end': 12842,
#   'start_time': '09:54:20',
#   'end_time': '09:57:20'},
#  {'ce_normaldiff': 149422.06654991242,
#   'pe_normaldiff': -32729.42206654991,
#   'pcr_in_window': -0.21904008438818565,
#   'nifty_start': 12842,
#   'nifty_end': 12818,
#   'start_time': '09:57:20',
#   'end_time': '10:06:51'},
#  {'ce_normaldiff': 304800.0,
#   'pe_normaldiff': 215600.0,
#   'pcr_in_window': 0.7073490813648294,
#   'nifty_start': 12818,
#   'nifty_end': 12816,
#   'start_time': '10:06:51',
#   'end_time': '10:08:21'},
#  {'ce_normaldiff': 352762.5,
#   'pe_normaldiff': 56670.0,
#   'pcr_in_window': 0.1606463272031466,
#   'nifty_start': 12816,
#   'nifty_end': 12851,
#   'start_time': '10:08:21',
#   'end_time': '10:18:21'},
#  {'ce_normaldiff': -706406.25,
#   'pe_normaldiff': 132562.5,
#   'pcr_in_window': -0.187657597876576,
#   'nifty_start': 12851,
#   'nifty_end': 12844,
#   'start_time': '10:18:21',
#   'end_time': '10:22:21'},
#  {'ce_normaldiff': 55628.57142857143,
#   'pe_normaldiff': 101335.71428571429,
#   'pcr_in_window': 1.8216486902927582,
#   'nifty_start': 12844,
#   'nifty_end': 12838,
#   'start_time': '10:22:21',
#   'end_time': '10:25:51'},
#  {'ce_normaldiff': 110408.82352941176,
#   'pe_normaldiff': 20426.470588235294,
#   'pcr_in_window': 0.1850075921042116,
#   'nifty_start': 12838,
#   'nifty_end': 12832,
#   'start_time': '10:25:51',
#   'end_time': '10:34:21'},
#  {'ce_normaldiff': 51681.818181818184,
#   'pe_normaldiff': 47986.36363636364,
#   'pcr_in_window': 0.9284960422163588,
#   'nifty_start': 12832,
#   'nifty_end': 12844,
#   'start_time': '10:34:21',
#   'end_time': '10:39:51'},
#  {'ce_normaldiff': 60052.04718945177,
#   'pe_normaldiff': 62784.52463566967,
#   'pcr_in_window': 1.045501820072803,
#   'nifty_start': 12844,
#   'nifty_end': 12845,
#   'start_time': '10:39:51',
#   'end_time': '11:03:52'},
#  {'ce_normaldiff': 51688.95763921942,
#   'pe_normaldiff': 37465.01665873394,
#   'pcr_in_window': 0.7248166411138276,
#   'nifty_start': 12845,
#   'nifty_end': 12832,
#   'start_time': '11:03:52',
#   'end_time': '11:38:53'},
#  {'ce_normaldiff': 57614.51612903226,
#   'pe_normaldiff': -56090.32258064516,
#   'pcr_in_window': -0.9735449735449735,
#   'nifty_start': 12832,
#   'nifty_end': 12819,
#   'start_time': '11:38:53',
#   'end_time': '11:54:23'}]
