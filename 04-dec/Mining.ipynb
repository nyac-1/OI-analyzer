# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime as dt
from datetime import datetime
import pickle5 as pickle
import threading
import os
import json
import time

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp"
curtime = datetime.now().strftime("%H:%M:%S")

#Create dataframe
strikes = [50*i for i in range(220,281)]
df=pd.DataFrame(columns = ['strike_price'], index = strikes)
for i in strikes:
    df.loc[i,'strike_price'] = i

# %%
def get_soup(url):
    response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    if(response.status_code != 200):
        print('Illegal URL')
        return None
    soup = BeautifulSoup(response.text,'lxml')
    print("Soup generation. 200!")
    return soup

# %%
def get_nifty(soup):
    try:
        val1 = soup.find_all('span')[0].text.split()[-1]
        val2 = soup.find_all('span')[1].text.split()[-2]
        return ({'nifty':val1,'time':val2})
    except:
        print("Bad request")
        return None

# %%
def insert_values(soup, nifty, dataframe):
    cols = [
        'CE_OI_@'+nifty['time'],
        'CE_CHOI_@'+nifty['time'],
        'CE_IV_@'+nifty['time'],
        'CE_LTP_@'+nifty['time'],
        'PE_OI_@'+nifty['time'],
        'PE_CHOI_@'+nifty['time'],
        'PE_IV_@'+nifty['time'],
        'PE_LTP_@'+nifty['time'],
        'NIFTY@'+nifty['time'],
        'CE_VOL_@'+nifty['time'],
        'PE_VOL_@'+nifty['time'],
        'CE_LTP_CHG_@'+nifty['time'],
        'PE_LTP_CHG_@'+nifty['time']
    ]
    
    for col in cols:
        dataframe[col] = np.nan
    
    for one in soup.find_all('div',{'class':'opttbldata'})[0].find_all('tr')[2:-1]:
        one = one.find_all('td')
        strike = one[11].text
        if(int(float(strike)) not in list(df['strike_price'])):
            continue
        values = dict()
        values[cols[0]] = one[1].text
        values[cols[1]] = one[2].text
        values[cols[2]] = one[4].text
        values[cols[3]] = one[5].text
        values[cols[4]] = one[21].text
        values[cols[5]] = one[20].text
        values[cols[6]] = one[18].text
        values[cols[7]] = one[17].text
        values[cols[8]] = nifty['nifty']
        values[cols[9]] = one[3].text
        values[cols[10]] = one[19].text
        values[cols[11]] = one[6].text
        values[cols[12]] = one[16].text
        
    
        for key in values:
            values[key] = values[key].replace(" ","")
            values[key] = values[key].replace("\t","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace("\r","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace(",","")
            try: 
                values[key] = float(values[key])
            except:
                values[key] = np.nan
            
            dataframe.loc[int(float(strike)),key] = values[key]

    return dataframe

# %%
def automation(curtime, df):
    
    soup = get_soup(url)
    nifty = get_nifty(soup)
    print(nifty)
    
    if(curtime == nifty['time']):
        print("Failed to add! time:"+curtime)
        return curtime,df
    else:
        cutime = nifty['time']
        
    df=insert_values(soup, nifty, df)
    df.to_csv('data.csv',index=True)
    
    return nifty['time'],df

# %%
#curtime,df = automation(curtime, df)

# %%
while True:
    print("Start")
    curtime,df = automation(curtime, df)
    time.sleep(60*5)
# Out:
# Start
# Soup generation. 200!
# {'nifty': '13166.15', 'time': '09:17:20'}
# Start
# Soup generation. 200!
# {'nifty': '13200.20', 'time': '09:34:50'}
# Start
# Soup generation. 200!
# {'nifty': '13196.75', 'time': '09:40:20'}
# Start
# Soup generation. 200!
# {'nifty': '13204.90', 'time': '09:44:20'}
# Start
# Soup generation. 200!
# {'nifty': '13202.20', 'time': '09:49:20'}
# Start
# Soup generation. 200!
# {'nifty': '13209.20', 'time': '09:55:50'}
# Start
# Soup generation. 200!
# {'nifty': '13212.00', 'time': '10:00:20'}
# Start
# Soup generation. 200!
# {'nifty': '13214.60', 'time': '10:08:51'}
# Start
# Soup generation. 200!
# {'nifty': '13233.30', 'time': '10:22:51'}
# Start
# Soup generation. 200!
# {'nifty': '13220.75', 'time': '10:26:21'}
# Start
# Soup generation. 200!
# {'nifty': '13239.25', 'time': '10:31:51'}
# Start
# Soup generation. 200!
# {'nifty': '13239.60', 'time': '10:35:51'}
# Start
# Soup generation. 200!
# {'nifty': '13240.20', 'time': '10:41:52'}
# Start
# Soup generation. 200!
# {'nifty': '13239.10', 'time': '10:46:52'}
# Start
# Soup generation. 200!
# {'nifty': '13243.70', 'time': '10:51:52'}
# Start
# Soup generation. 200!
# {'nifty': '13238.60', 'time': '10:56:52'}
# Start
# Soup generation. 200!
# {'nifty': '13231.45', 'time': '11:01:52'}
# Start
# Soup generation. 200!
# {'nifty': '13239.35', 'time': '11:07:22'}
# Start
# Soup generation. 200!
# {'nifty': '13247.25', 'time': '11:11:52'}
# Start
# Soup generation. 200!
# {'nifty': '13232.05', 'time': '11:16:52'}
# Start
# Soup generation. 200!
# {'nifty': '13225.20', 'time': '11:22:23'}
# Start
# Soup generation. 200!
# {'nifty': '13220.45', 'time': '11:28:23'}
# Start
# Soup generation. 200!
# {'nifty': '13215.95', 'time': '11:31:53'}
# Start
# Soup generation. 200!
# {'nifty': '13207.50', 'time': '11:37:53'}
# Start
# Soup generation. 200!
# {'nifty': '13207.05', 'time': '11:42:23'}
# Start
# Soup generation. 200!
# {'nifty': '13214.35', 'time': '11:46:53'}
# Start
# Soup generation. 200!
# {'nifty': '13215.75', 'time': '11:52:23'}
# Start
# Soup generation. 200!
# {'nifty': '13218.55', 'time': '11:57:54'}
# Start
# Soup generation. 200!
# {'nifty': '13206.45', 'time': '12:01:24'}
# Start
# Soup generation. 200!
# {'nifty': '13209.85', 'time': '12:06:54'}
# Start
# Soup generation. 200!
# {'nifty': '13213.80', 'time': '12:12:54'}
# Start
# Soup generation. 200!
# {'nifty': '13211.60', 'time': '12:17:54'}
# Start
# Soup generation. 200!
# {'nifty': '13206.50', 'time': '12:22:24'}
# Start
# Soup generation. 200!
# {'nifty': '13209.10', 'time': '12:27:24'}
# Start
# Soup generation. 200!
# {'nifty': '13201.05', 'time': '12:31:54'}
# Start
# Soup generation. 200!
# {'nifty': '13196.55', 'time': '12:35:55'}
# Start
# Soup generation. 200!
# {'nifty': '13189.25', 'time': '12:42:25'}
# Start
# Soup generation. 200!
# {'nifty': '13186.40', 'time': '12:48:25'}
# Start
# Soup generation. 200!
# {'nifty': '13165.45', 'time': '12:51:55'}
# Start
# Soup generation. 200!
# {'nifty': '13161.25', 'time': '12:57:25'}
# Start
# Soup generation. 200!
# {'nifty': '13173.00', 'time': '13:02:25'}
# Start
# Soup generation. 200!
# {'nifty': '13184.35', 'time': '13:08:25'}
# Start
# Soup generation. 200!
# {'nifty': '13187.10', 'time': '13:11:55'}
# Start
# Soup generation. 200!
# {'nifty': '13183.00', 'time': '13:18:55'}
# Start
# Soup generation. 200!
# {'nifty': '13194.55', 'time': '13:22:26'}
# Start
# Soup generation. 200!
# {'nifty': '13206.45', 'time': '13:26:26'}
# Start
# Soup generation. 200!
# {'nifty': '13206.50', 'time': '13:33:56'}
# Start
# Soup generation. 200!
# {'nifty': '13210.05', 'time': '13:40:56'}
# Start
# Soup generation. 200!
# {'nifty': '13216.50', 'time': '13:44:56'}
# Start
# Soup generation. 200!
# {'nifty': '13208.25', 'time': '13:51:26'}
# Start
# Soup generation. 200!
# {'nifty': '13195.30', 'time': '13:54:26'}
# Start
# Soup generation. 200!
# {'nifty': '13209.35', 'time': '13:59:26'}
# Start
# Soup generation. 200!
# {'nifty': '13208.20', 'time': '14:05:27'}
# Start
# Soup generation. 200!
# {'nifty': '13207.45', 'time': '14:10:57'}
# Start
# Soup generation. 200!
# {'nifty': '13196.25', 'time': '14:14:57'}
# Start
# Soup generation. 200!
# {'nifty': '13201.70', 'time': '14:20:27'}
# Start
# Soup generation. 200!
# {'nifty': '13210.00', 'time': '14:25:27'}
# Start
# Soup generation. 200!
# {'nifty': '13224.80', 'time': '14:29:57'}
# Start
# Soup generation. 200!
# {'nifty': '13219.85', 'time': '14:35:27'}
# Start
# Soup generation. 200!
# {'nifty': '13230.65', 'time': '14:40:58'}
# Start
# Soup generation. 200!
# {'nifty': '13236.90', 'time': '14:46:28'}
# Start
# Soup generation. 200!
# {'nifty': '13240.70', 'time': '14:49:58'}
# Start
# Soup generation. 200!
# {'nifty': '13240.80', 'time': '14:55:58'}
# Start
# Soup generation. 200!
# {'nifty': '13246.40', 'time': '15:00:58'}
# Start
# Soup generation. 200!
# {'nifty': '13251.30', 'time': '15:05:28'}
# Start
# Soup generation. 200!
# {'nifty': '13249.55', 'time': '15:10:29'}
# Start
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f912f641460>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='www1.nseindia.com', port=443): Max retries exceeded with url: /live_market/dynaContent/live_watch/option_chain/optionKeys.jsp (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f912f641460>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-1de6d0e6e1a4> in <module>
#       1 while True:
#       2     print("Start")
# ----> 3     curtime,df = automation(curtime, df)
#       4     time.sleep(60*5)
#
# <ipython-input-6-bb4f5ff9c158> in automation(curtime, df)
#       1 def automation(curtime, df):
#       2
# ----> 3     soup = get_soup(url)
#       4     nifty = get_nifty(soup)
#       5     print(nifty)
#
# <ipython-input-3-824aaf95fcf4> in get_soup(url)
#       1 def get_soup(url):
# ----> 2     response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
#       3     if(response.status_code != 200):
#       4         print('Illegal URL')
#       5         return None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www1.nseindia.com', port=443): Max retries exceeded with url: /live_market/dynaContent/live_watch/option_chain/optionKeys.jsp (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f912f641460>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
