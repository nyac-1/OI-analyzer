# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime as dt
from datetime import datetime
import pickle5 as pickle
import threading
import os
import json
import time

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp"
curtime = datetime.now().strftime("%H:%M:%S")

#Create dataframe
strikes = [50*i for i in range(220,281)]
df=pd.DataFrame(columns = ['strike_price'], index = strikes)
for i in strikes:
    df.loc[i,'strike_price'] = i

# %%
def get_soup(url):
    response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    if(response.status_code != 200):
        print('Illegal URL')
        return None
    soup = BeautifulSoup(response.text,'lxml')
    print("Soup generation. 200!")
    return soup

# %%
def get_nifty(soup):
    try:
        val1 = soup.find_all('span')[0].text.split()[-1]
        val2 = soup.find_all('span')[1].text.split()[-2]
        return ({'nifty':val1,'time':val2})
    except:
        print("Bad request")
        return None

# %%
def insert_values(soup, nifty, dataframe):
    cols = [
        'CE_OI_@'+nifty['time'],
        'CE_CHOI_@'+nifty['time'],
        'CE_IV_@'+nifty['time'],
        'CE_LTP_@'+nifty['time'],
        'PE_OI_@'+nifty['time'],
        'PE_CHOI_@'+nifty['time'],
        'PE_IV_@'+nifty['time'],
        'PE_LTP_@'+nifty['time'],
        'NIFTY@'+nifty['time'],
        'CE_VOL_@'+nifty['time'],
        'PE_VOL_@'+nifty['time'],
        'CE_LTP_CHG_@'+nifty['time'],
        'PE_LTP_CHG_@'+nifty['time']
    ]
    
    for col in cols:
        dataframe[col] = np.nan
    
    for one in soup.find_all('div',{'class':'opttbldata'})[0].find_all('tr')[2:-1]:
        one = one.find_all('td')
        strike = one[11].text
        if(int(float(strike)) not in list(df['strike_price'])):
            continue
        values = dict()
        values[cols[0]] = one[1].text
        values[cols[1]] = one[2].text
        values[cols[2]] = one[4].text
        values[cols[3]] = one[5].text
        values[cols[4]] = one[21].text
        values[cols[5]] = one[20].text
        values[cols[6]] = one[18].text
        values[cols[7]] = one[17].text
        values[cols[8]] = nifty['nifty']
        values[cols[9]] = one[3].text
        values[cols[10]] = one[19].text
        values[cols[11]] = one[6].text
        values[cols[12]] = one[16].text
        
    
        for key in values:
            values[key] = values[key].replace(" ","")
            values[key] = values[key].replace("\t","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace("\r","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace(",","")
            try: 
                values[key] = float(values[key])
            except:
                values[key] = np.nan
            
            dataframe.loc[int(float(strike)),key] = values[key]

    return dataframe

# %%
def automation(curtime, df):
    
    soup = get_soup(url)
    nifty = get_nifty(soup)
    print(nifty)
    
    if(curtime == nifty['time']):
        print("Failed to add! time:"+curtime)
        return curtime,df
    else:
        cutime = nifty['time']
        
    df=insert_values(soup, nifty, df)
    df.to_csv('data.csv',index=True)
    
    return nifty['time'],df

# %%
#curtime,df = automation(curtime, df)

# %%
while True:
    print("Start")
    curtime,df = automation(curtime, df)
    time.sleep(60*5)
# Out:
# Start
# Soup generation. 200!
# {'nifty': '13574.40', 'time': '09:17:50'}
# Start
# Soup generation. 200!
# {'nifty': '13584.00', 'time': '09:24:20'}
# Start
# Soup generation. 200!
# {'nifty': '13571.75', 'time': '09:27:20'}
# Start
# Soup generation. 200!
# {'nifty': '13569.55', 'time': '09:33:20'}
# Start
# Soup generation. 200!
# {'nifty': '13559.70', 'time': '09:54:21'}
# Start
# Soup generation. 200!
# {'nifty': '13546.85', 'time': '09:59:21'}
# Start
# Soup generation. 200!
# {'nifty': '13547.60', 'time': '10:03:21'}
# Start
# Soup generation. 200!
# {'nifty': '13535.95', 'time': '10:20:21'}
# Start
# Soup generation. 200!
# {'nifty': '13545.30', 'time': '10:26:51'}
# Start
# Soup generation. 200!
# {'nifty': '13542.05', 'time': '10:31:22'}
# Start
# Soup generation. 200!
# {'nifty': '13536.05', 'time': '10:36:21'}
# Start
# Soup generation. 200!
# {'nifty': '13525.25', 'time': '10:39:52'}
# Start
# Soup generation. 200!
# {'nifty': '13530.50', 'time': '10:45:22'}
# Start
# Soup generation. 200!
# {'nifty': '13539.25', 'time': '10:50:22'}
# Start
# Soup generation. 200!
# {'nifty': '13535.00', 'time': '10:55:22'}
# Start
# Soup generation. 200!
# {'nifty': '13532.45', 'time': '11:01:52'}
# Start
# Soup generation. 200!
# {'nifty': '13514.45', 'time': '11:05:22'}
# Start
# Soup generation. 200!
# {'nifty': '13522.55', 'time': '11:10:22'}
# Start
# Soup generation. 200!
# {'nifty': '13524.05', 'time': '11:37:23'}
# Start
# Soup generation. 200!
# {'nifty': '13520.25', 'time': '11:43:23'}
# Start
# Soup generation. 200!
# {'nifty': '13515.40', 'time': '11:45:53'}
# Start
# Soup generation. 200!
# {'nifty': '13514.75', 'time': '11:56:53'}
# Start
# Soup generation. 200!
# {'nifty': '13517.65', 'time': '12:01:53'}
# Start
# Soup generation. 200!
# {'nifty': '13516.25', 'time': '12:07:23'}
# Start
# Soup generation. 200!
# {'nifty': '13517.30', 'time': '12:10:53'}
# Start
# Soup generation. 200!
# {'nifty': '13522.80', 'time': '12:16:54'}
# Start
# Soup generation. 200!
# {'nifty': '13518.10', 'time': '12:22:54'}
# Start
# Soup generation. 200!
# {'nifty': '13520.20', 'time': '12:27:24'}
# Start
# Soup generation. 200!
# {'nifty': '13526.30', 'time': '12:32:24'}
# Start
# Soup generation. 200!
# {'nifty': '13523.70', 'time': '12:38:54'}
# Start
# Soup generation. 200!
# {'nifty': '13527.00', 'time': '12:41:54'}
# Start
# Soup generation. 200!
# {'nifty': '13528.90', 'time': '12:47:54'}
# Start
# Soup generation. 200!
# {'nifty': '13530.50', 'time': '12:52:24'}
# Start
# Soup generation. 200!
# {'nifty': '13480.20', 'time': '12:57:25'}
# Start
# Soup generation. 200!
# {'nifty': '13493.60', 'time': '13:02:55'}
# Start
# Soup generation. 200!
# {'nifty': '13513.65', 'time': '13:07:55'}
# Start
# Soup generation. 200!
# {'nifty': '13521.65', 'time': '13:12:55'}
# Start
# Soup generation. 200!
# {'nifty': '13529.70', 'time': '13:18:55'}
# Start
# Soup generation. 200!
# {'nifty': '13522.35', 'time': '13:21:55'}
# Start
# Soup generation. 200!
# {'nifty': '13534.60', 'time': '13:26:55'}
# Start
# Soup generation. 200!
# {'nifty': '13519.95', 'time': '13:31:55'}
# Start
# Soup generation. 200!
# {'nifty': '13527.40', 'time': '13:37:25'}
# Start
# Soup generation. 200!
# {'nifty': '13533.20', 'time': '13:41:56'}
# Start
# Soup generation. 200!
# {'nifty': '13539.00', 'time': '13:46:56'}
# Start
# Soup generation. 200!
# {'nifty': '13528.80', 'time': '13:56:26'}
# Start
# Soup generation. 200!
# {'nifty': '13548.35', 'time': '14:04:26'}
# Start
# Soup generation. 200!
# {'nifty': '13552.45', 'time': '14:13:26'}
# Start
# Soup generation. 200!
# {'nifty': '13550.75', 'time': '14:20:26'}
# Start
# Soup generation. 200!
# {'nifty': '13557.15', 'time': '14:29:27'}
# Start
# Soup generation. 200!
# {'nifty': '13553.60', 'time': '14:34:57'}
# Start
# Soup generation. 200!
# {'nifty': '13549.60', 'time': '14:38:27'}
# Start
# Soup generation. 200!
# {'nifty': '13552.50', 'time': '14:43:27'}
# Start
# Soup generation. 200!
# {'nifty': '13559.75', 'time': '14:48:57'}
# Start
# Soup generation. 200!
# {'nifty': '13552.90', 'time': '14:54:57'}
# Start
# Soup generation. 200!
# {'nifty': '13556.45', 'time': '14:58:58'}
# Start
# Soup generation. 200!
# {'nifty': '13553.70', 'time': '15:04:28'}
# Start
# Soup generation. 200!
# {'nifty': '13563.25', 'time': '15:09:58'}
# Start
# Soup generation. 200!
# {'nifty': '13562.65', 'time': '15:14:58'}
# Start
# Soup generation. 200!
# {'nifty': '13557.10', 'time': '15:22:58'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1de6d0e6e1a4> in <module>
#       2     print("Start")
#       3     curtime,df = automation(curtime, df)
# ----> 4     time.sleep(60*5)
#
# KeyboardInterrupt:
