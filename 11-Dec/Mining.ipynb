# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime as dt
from datetime import datetime
import pickle5 as pickle
import threading
import os
import json
import time

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp"
curtime = datetime.now().strftime("%H:%M:%S")

#Create dataframe
strikes = [50*i for i in range(220,281)]
df=pd.DataFrame(columns = ['strike_price'], index = strikes)
for i in strikes:
    df.loc[i,'strike_price'] = i

# %%
def get_soup(url):
    response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    if(response.status_code != 200):
        print('Illegal URL')
        return None
    soup = BeautifulSoup(response.text,'lxml')
    print("Soup generation. 200!")
    return soup

# %%
def get_nifty(soup):
    try:
        val1 = soup.find_all('span')[0].text.split()[-1]
        val2 = soup.find_all('span')[1].text.split()[-2]
        return ({'nifty':val1,'time':val2})
    except:
        print("Bad request")
        return None

# %%
def insert_values(soup, nifty, dataframe):
    cols = [
        'CE_OI_@'+nifty['time'],
        'CE_CHOI_@'+nifty['time'],
        'CE_IV_@'+nifty['time'],
        'CE_LTP_@'+nifty['time'],
        'PE_OI_@'+nifty['time'],
        'PE_CHOI_@'+nifty['time'],
        'PE_IV_@'+nifty['time'],
        'PE_LTP_@'+nifty['time'],
        'NIFTY@'+nifty['time'],
        'CE_VOL_@'+nifty['time'],
        'PE_VOL_@'+nifty['time'],
        'CE_LTP_CHG_@'+nifty['time'],
        'PE_LTP_CHG_@'+nifty['time']
    ]
    
    for col in cols:
        dataframe[col] = np.nan
    
    for one in soup.find_all('div',{'class':'opttbldata'})[0].find_all('tr')[2:-1]:
        one = one.find_all('td')
        strike = one[11].text
        if(int(float(strike)) not in list(df['strike_price'])):
            continue
        values = dict()
        values[cols[0]] = one[1].text
        values[cols[1]] = one[2].text
        values[cols[2]] = one[4].text
        values[cols[3]] = one[5].text
        values[cols[4]] = one[21].text
        values[cols[5]] = one[20].text
        values[cols[6]] = one[18].text
        values[cols[7]] = one[17].text
        values[cols[8]] = nifty['nifty']
        values[cols[9]] = one[3].text
        values[cols[10]] = one[19].text
        values[cols[11]] = one[6].text
        values[cols[12]] = one[16].text
        
    
        for key in values:
            values[key] = values[key].replace(" ","")
            values[key] = values[key].replace("\t","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace("\r","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace(",","")
            try: 
                values[key] = float(values[key])
            except:
                values[key] = np.nan
            
            dataframe.loc[int(float(strike)),key] = values[key]

    return dataframe

# %%
def automation(curtime, df):
    
    soup = get_soup(url)
    nifty = get_nifty(soup)
    print(nifty)
    
    if(curtime == nifty['time']):
        print("Failed to add! time:"+curtime)
        return curtime,df
    else:
        cutime = nifty['time']
        
    df=insert_values(soup, nifty, df)
    df.to_csv('data.csv',index=True)
    
    return nifty['time'],df

# %%
#curtime,df = automation(curtime, df)

# %%
while True:
    print("Start")
    curtime,df = automation(curtime, df)
    time.sleep(60*5)
# Out:
# Start
# Soup generation. 200!
# {'nifty': '13549.70', 'time': '09:34:22'}
# Start
# Soup generation. 200!
# {'nifty': '13548.65', 'time': '09:53:52'}
# Start
# Soup generation. 200!
# {'nifty': '13549.20', 'time': '09:57:22'}
# Start
# Soup generation. 200!
# {'nifty': '13545.60', 'time': '10:03:22'}
# Start
# Soup generation. 200!
# {'nifty': '13549.45', 'time': '10:06:52'}
# Start
# Soup generation. 200!
# {'nifty': '13559.00', 'time': '10:12:53'}
# Start
# Soup generation. 200!
# {'nifty': '13557.40', 'time': '10:17:23'}
# Start
# Soup generation. 200!
# {'nifty': '13571.05', 'time': '10:22:23'}
# Start
# Soup generation. 200!
# {'nifty': '13568.70', 'time': '10:27:53'}
# Start
# Soup generation. 200!
# {'nifty': '13571.00', 'time': '10:33:53'}
# Start
# Soup generation. 200!
# {'nifty': '13576.40', 'time': '10:37:53'}
# Start
# Soup generation. 200!
# {'nifty': '13563.15', 'time': '10:42:53'}
# Start
# Soup generation. 200!
# {'nifty': '13559.35', 'time': '10:47:24'}
# Start
# Soup generation. 200!
# {'nifty': '13564.15', 'time': '10:53:24'}
# Start
# Soup generation. 200!
# {'nifty': '13561.75', 'time': '10:58:24'}
# Start
# Soup generation. 200!
# {'nifty': '13563.35', 'time': '11:03:24'}
# Start
# Soup generation. 200!
# {'nifty': '13566.70', 'time': '11:07:24'}
# Start
# Soup generation. 200!
# {'nifty': '13553.75', 'time': '11:13:24'}
# Start
# Soup generation. 200!
# {'nifty': '13555.55', 'time': '11:16:54'}
# Start
# Soup generation. 200!
# {'nifty': '13548.45', 'time': '11:24:24'}
# Start
# Soup generation. 200!
# {'nifty': '13533.30', 'time': '11:47:25'}
# Start
# Soup generation. 200!
# {'nifty': '13542.65', 'time': '11:59:55'}
# Start
# Soup generation. 200!
# {'nifty': '13543.10', 'time': '12:10:55'}
# Start
# Soup generation. 200!
# {'nifty': '13552.10', 'time': '12:16:26'}
# Start
# Soup generation. 200!
# {'nifty': '13548.65', 'time': '12:21:26'}
# Start
# Soup generation. 200!
# {'nifty': '13548.75', 'time': '12:25:26'}
# Start
# Soup generation. 200!
# {'nifty': '13555.15', 'time': '12:30:56'}
# Start
# Soup generation. 200!
# {'nifty': '13558.50', 'time': '12:36:26'}
# Start
# Soup generation. 200!
# {'nifty': '13560.75', 'time': '12:40:26'}
# Start
# Soup generation. 200!
# {'nifty': '13559.20', 'time': '12:46:56'}
# Start
# Soup generation. 200!
# {'nifty': '13564.65', 'time': '12:50:26'}
# Start
# Soup generation. 200!
# {'nifty': '13559.95', 'time': '12:56:26'}
# Start
# Soup generation. 200!
# {'nifty': '13551.40', 'time': '13:01:56'}
# Start
# Soup generation. 200!
# {'nifty': '13556.30', 'time': '13:05:56'}
# Start
# Soup generation. 200!
# {'nifty': '13546.15', 'time': '13:11:57'}
# Start
# Soup generation. 200!
# {'nifty': '13547.60', 'time': '13:17:27'}
# Start
# Soup generation. 200!
# {'nifty': '13544.10', 'time': '13:21:27'}
# Start
# Soup generation. 200!
# {'nifty': '13544.45', 'time': '13:25:57'}
# Start
# Soup generation. 200!
# {'nifty': '13525.25', 'time': '13:31:57'}
# Start
# Soup generation. 200!
# {'nifty': '13529.10', 'time': '13:34:57'}
# Start
# Soup generation. 200!
# {'nifty': '13532.05', 'time': '13:41:27'}
# Start
# Soup generation. 200!
# {'nifty': '13530.60', 'time': '13:46:28'}
# Start
# Soup generation. 200!
# {'nifty': '13521.35', 'time': '13:50:58'}
# Start
# Soup generation. 200!
# {'nifty': '13520.70', 'time': '13:55:58'}
# Start
# Soup generation. 200!
# {'nifty': '13485.95', 'time': '14:01:58'}
# Start
# Soup generation. 200!
# {'nifty': '13469.60', 'time': '14:05:58'}
# Start
# Soup generation. 200!
# {'nifty': '13468.50', 'time': '14:11:58'}
# Start
# Soup generation. 200!
# {'nifty': '13431.30', 'time': '14:15:58'}
# Start
# Soup generation. 200!
# {'nifty': '13408.80', 'time': '14:20:29'}
# Start
# Soup generation. 200!
# {'nifty': '13438.20', 'time': '14:25:59'}
# Start
# Soup generation. 200!
# {'nifty': '13465.85', 'time': '14:32:29'}
# Start
# Soup generation. 200!
# {'nifty': '13479.15', 'time': '14:35:59'}
# Start
# Soup generation. 200!
# {'nifty': '13474.20', 'time': '14:41:29'}
# Start
# Soup generation. 200!
# {'nifty': '13463.05', 'time': '14:46:59'}
# Start
# Soup generation. 200!
# {'nifty': '13492.35', 'time': '14:50:59'}
# Start
# Soup generation. 200!
# {'nifty': '13484.65', 'time': '14:56:29'}
# Start
# Soup generation. 200!
# {'nifty': '13502.00', 'time': '15:03:29'}
# Start
# Soup generation. 200!
# {'nifty': '13508.35', 'time': '15:09:00'}
# Start
# Soup generation. 200!
# {'nifty': '13513.15', 'time': '15:14:00'}
# Start
# Soup generation. 200!
# {'nifty': '13525.95', 'time': '15:17:30'}
# Start
# Soup generation. 200!
# {'nifty': '13518.85', 'time': '15:23:30'}
# Start
# Soup generation. 200!
# {'nifty': '13512.15', 'time': '15:28:30'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1de6d0e6e1a4> in <module>
#       2     print("Start")
#       3     curtime,df = automation(curtime, df)
# ----> 4     time.sleep(60*5)
#
# KeyboardInterrupt:
