# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime as dt
from datetime import datetime
import pickle5 as pickle
import threading
import os
import json
import time

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp"
curtime = datetime.now().strftime("%H:%M:%S")

#Create dataframe
strikes = [50*i for i in range(220,281)]
df=pd.DataFrame(columns = ['strike_price'], index = strikes)
for i in strikes:
    df.loc[i,'strike_price'] = i

# %%
def get_soup(url):
    response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    if(response.status_code != 200):
        print('Illegal URL')
        return None
    soup = BeautifulSoup(response.text,'lxml')
    print("Soup generation. 200!")
    return soup

# %%
def get_nifty(soup):
    try:
        val1 = soup.find_all('span')[0].text.split()[-1]
        val2 = soup.find_all('span')[1].text.split()[-2]
        return ({'nifty':val1,'time':val2})
    except:
        print("Bad request")
        return None

# %%
def insert_values(soup, nifty, dataframe):
    cols = [
        'CE_OI_@'+nifty['time'],
        'CE_CHOI_@'+nifty['time'],
        'CE_IV_@'+nifty['time'],
        'CE_LTP_@'+nifty['time'],
        'PE_OI_@'+nifty['time'],
        'PE_CHOI_@'+nifty['time'],
        'PE_IV_@'+nifty['time'],
        'PE_LTP_@'+nifty['time'],
        'NIFTY@'+nifty['time'],
        'CE_VOL_@'+nifty['time'],
        'PE_VOL_@'+nifty['time'],
        'CE_LTP_CHG_@'+nifty['time'],
        'PE_LTP_CHG_@'+nifty['time']
    ]
    
    for col in cols:
        dataframe[col] = np.nan
    
    for one in soup.find_all('div',{'class':'opttbldata'})[0].find_all('tr')[2:-1]:
        one = one.find_all('td')
        strike = one[11].text
        if(int(float(strike)) not in list(df['strike_price'])):
            continue
        values = dict()
        values[cols[0]] = one[1].text
        values[cols[1]] = one[2].text
        values[cols[2]] = one[4].text
        values[cols[3]] = one[5].text
        values[cols[4]] = one[21].text
        values[cols[5]] = one[20].text
        values[cols[6]] = one[18].text
        values[cols[7]] = one[17].text
        values[cols[8]] = nifty['nifty']
        values[cols[9]] = one[3].text
        values[cols[10]] = one[19].text
        values[cols[11]] = one[6].text
        values[cols[12]] = one[16].text
        
    
        for key in values:
            values[key] = values[key].replace(" ","")
            values[key] = values[key].replace("\t","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace("\r","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace(",","")
            try: 
                values[key] = float(values[key])
            except:
                values[key] = np.nan
            
            dataframe.loc[int(float(strike)),key] = values[key]

    return dataframe

# %%
def automation(curtime, df):
    
    soup = get_soup(url)
    nifty = get_nifty(soup)
    print(nifty)
    
    if(curtime == nifty['time']):
        print("Failed to add! time:"+curtime)
        return curtime,df
    else:
        cutime = nifty['time']
        
    df=insert_values(soup, nifty, df)
    df.to_csv('data.csv',index=True)
    
    return nifty['time'],df

# %%
#curtime,df = automation(curtime, df)

# %%
while True:
    print("Start")
    curtime,df = automation(curtime, df)
    time.sleep(60*5)
# Out:
# Start
# Soup generation. 200!
# {'nifty': '13267.30', 'time': '09:17:50'}
# Start
# Soup generation. 200!
# {'nifty': '13279.00', 'time': '09:22:50'}
# Start
# Soup generation. 200!
# {'nifty': '13283.80', 'time': '09:28:20'}
# Start
# Soup generation. 200!
# {'nifty': '13281.45', 'time': '09:32:20'}
# Start
# Soup generation. 200!
# {'nifty': '13303.00', 'time': '09:38:20'}
# Start
# Soup generation. 200!
# {'nifty': '13308.25', 'time': '09:43:21'}
# Start
# Soup generation. 200!
# {'nifty': '13310.70', 'time': '09:48:51'}
# Start
# Soup generation. 200!
# {'nifty': '13309.30', 'time': '09:51:51'}
# Start
# Soup generation. 200!
# {'nifty': '13308.20', 'time': '09:58:21'}
# Start
# Soup generation. 200!
# {'nifty': '13290.80', 'time': '10:02:51'}
# Start
# Soup generation. 200!
# {'nifty': '13302.20', 'time': '10:08:21'}
# Start
# Soup generation. 200!
# {'nifty': '13300.80', 'time': '10:12:21'}
# Start
# Soup generation. 200!
# {'nifty': '13291.35', 'time': '10:16:51'}
# Start
# Soup generation. 200!
# {'nifty': '13281.90', 'time': '10:23:51'}
# Start
# Soup generation. 200!
# {'nifty': '13284.75', 'time': '10:28:52'}
# Start
# Soup generation. 200!
# {'nifty': '13285.35', 'time': '10:32:22'}
# Start
# Soup generation. 200!
# {'nifty': '13289.95', 'time': '10:38:22'}
# Start
# Soup generation. 200!
# {'nifty': '13302.35', 'time': '10:43:22'}
# Start
# Soup generation. 200!
# {'nifty': '13301.05', 'time': '10:47:22'}
# Start
# Soup generation. 200!
# {'nifty': '13298.80', 'time': '10:52:22'}
# Start
# Soup generation. 200!
# {'nifty': '13296.70', 'time': '10:58:22'}
# Start
# Soup generation. 200!
# {'nifty': '13297.55', 'time': '11:03:22'}
# Start
# Soup generation. 200!
# {'nifty': '13296.50', 'time': '11:06:52'}
# Start
# Soup generation. 200!
# {'nifty': '13288.45', 'time': '11:12:53'}
# Start
# Soup generation. 200!
# {'nifty': '13295.60', 'time': '11:18:23'}
# Start
# Soup generation. 200!
# {'nifty': '13296.10', 'time': '11:23:53'}
# Start
# Soup generation. 200!
# {'nifty': '13297.65', 'time': '11:27:53'}
# Start
# Soup generation. 200!
# {'nifty': '13295.40', 'time': '11:33:23'}
# Start
# Soup generation. 200!
# {'nifty': '13289.20', 'time': '11:36:23'}
# Start
# Soup generation. 200!
# {'nifty': '13287.25', 'time': '11:42:23'}
# Start
# Soup generation. 200!
# {'nifty': '13292.60', 'time': '11:47:23'}
# Start
# Soup generation. 200!
# {'nifty': '13297.50', 'time': '11:53:54'}
# Start
# Soup generation. 200!
# {'nifty': '13293.30', 'time': '11:57:24'}
# Start
# Soup generation. 200!
# {'nifty': '13292.85', 'time': '12:02:24'}
# Start
# Soup generation. 200!
# {'nifty': '13299.35', 'time': '12:08:24'}
# Start
# Soup generation. 200!
# {'nifty': '13326.55', 'time': '12:12:24'}
# Start
# Soup generation. 200!
# {'nifty': '13327.35', 'time': '12:17:24'}
# Start
# Soup generation. 200!
# {'nifty': '13323.95', 'time': '12:22:54'}
# Start
# Soup generation. 200!
# {'nifty': '13326.45', 'time': '12:28:24'}
# Start
# Soup generation. 200!
# {'nifty': '13316.00', 'time': '12:32:55'}
# Start
# Soup generation. 200!
# {'nifty': '13321.75', 'time': '12:37:55'}
# Start
# Soup generation. 200!
# {'nifty': '13330.90', 'time': '12:42:55'}
# Start
# Soup generation. 200!
# {'nifty': '13330.25', 'time': '12:46:55'}
# Start
# Soup generation. 200!
# {'nifty': '13327.00', 'time': '12:51:55'}
# Start
# Soup generation. 200!
# {'nifty': '13339.95', 'time': '12:57:55'}
# Start
# Soup generation. 200!
# {'nifty': '13331.40', 'time': '13:03:25'}
# Start
# Soup generation. 200!
# {'nifty': '13330.45', 'time': '13:07:55'}
# Start
# Soup generation. 200!
# {'nifty': '13336.50', 'time': '13:13:25'}
# Start
# Soup generation. 200!
# {'nifty': '13332.45', 'time': '13:18:56'}
# Start
# Soup generation. 200!
# {'nifty': '13347.40', 'time': '13:23:56'}
# Start
# Soup generation. 200!
# {'nifty': '13348.05', 'time': '13:27:56'}
# Start
# Soup generation. 200!
# {'nifty': '13330.90', 'time': '13:32:56'}
# Start
# Soup generation. 200!
# {'nifty': '13323.40', 'time': '13:39:26'}
# Start
# Soup generation. 200!
# {'nifty': '13311.95', 'time': '13:42:26'}
# Start
# Soup generation. 200!
# {'nifty': '13325.30', 'time': '13:47:26'}
# Start
# Soup generation. 200!
# {'nifty': '13318.35', 'time': '13:53:26'}
# Start
# Soup generation. 200!
# {'nifty': '13322.50', 'time': '13:56:56'}
# Start
# Soup generation. 200!
# {'nifty': '13297.35', 'time': '14:02:27'}
# Start
# Soup generation. 200!
# {'nifty': '13307.60', 'time': '14:08:27'}
# Start
# Soup generation. 200!
# {'nifty': '13310.35', 'time': '14:13:57'}
# Start
# Soup generation. 200!
# {'nifty': '13307.15', 'time': '14:17:57'}
# Start
# Soup generation. 200!
# {'nifty': '13316.35', 'time': '14:22:27'}
# Start
# Soup generation. 200!
# {'nifty': '13330.00', 'time': '14:28:27'}
# Start
# Soup generation. 200!
# {'nifty': '13326.35', 'time': '14:32:27'}
# Start
# Soup generation. 200!
# {'nifty': '13322.90', 'time': '14:37:28'}
# Start
# Soup generation. 200!
# {'nifty': '13324.00', 'time': '14:43:58'}
# Start
# Soup generation. 200!
# {'nifty': '13336.25', 'time': '14:48:58'}
# Start
# Soup generation. 200!
# {'nifty': '13336.50', 'time': '14:52:58'}
# Start
# Soup generation. 200!
# {'nifty': '13350.20', 'time': '14:57:58'}
# Start
# Soup generation. 200!
# {'nifty': '13356.35', 'time': '15:03:28'}
# Start
# Soup generation. 200!
# {'nifty': '13363.40', 'time': '15:09:28'}
# Start
# Soup generation. 200!
# {'nifty': '13358.75', 'time': '15:14:58'}
# Start
# Soup generation. 200!
# {'nifty': '13354.80', 'time': '15:18:59'}
# Start
# Soup generation. 200!
# {'nifty': '13355.95', 'time': '15:22:29'}
# Start
# Soup generation. 200!
# {'nifty': '13355.30', 'time': '15:29:29'}
# Start
# Soup generation. 200!
# {'nifty': '13354.05', 'time': '15:30:29'}
# Start
# Soup generation. 200!
# {'nifty': '13354.05', 'time': '15:30:29'}
# Failed to add! time:15:30:29
# Start
# Soup generation. 200!
# {'nifty': '13355.75', 'time': '15:30:29'}
# Failed to add! time:15:30:29
# Start
# Soup generation. 200!
# {'nifty': '13355.75', 'time': '15:30:29'}
# Failed to add! time:15:30:29
# Start
# Soup generation. 200!
# {'nifty': '13355.75', 'time': '15:30:29'}
# Failed to add! time:15:30:29
