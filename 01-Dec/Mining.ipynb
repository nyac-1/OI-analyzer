# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime as dt
from datetime import datetime
import pickle5 as pickle
import threading
import os
import json
import time

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp"
curtime = datetime.now().strftime("%H:%M:%S")

#Create dataframe
strikes = [50*i for i in range(220,281)]
df=pd.DataFrame(columns = ['strike_price'], index = strikes)
for i in strikes:
    df.loc[i,'strike_price'] = i

# %%
def get_soup(url):
    response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    if(response.status_code != 200):
        print('Illegal URL')
        return None
    soup = BeautifulSoup(response.text,'lxml')
    print("Soup generation. 200!")
    return soup

# %%
def get_nifty(soup):
    try:
        val1 = soup.find_all('span')[0].text.split()[-1]
        val2 = soup.find_all('span')[1].text.split()[-2]
        return ({'nifty':val1,'time':val2})
    except:
        print("Bad request")
        return None

# %%
def insert_values(soup, nifty, dataframe):
    cols = [
        'CE_OI_@'+nifty['time'],
        'CE_CHOI_@'+nifty['time'],
        'CE_IV_@'+nifty['time'],
        'CE_LTP_@'+nifty['time'],
        'PE_OI_@'+nifty['time'],
        'PE_CHOI_@'+nifty['time'],
        'PE_IV_@'+nifty['time'],
        'PE_LTP_@'+nifty['time'],
        'NIFTY@'+nifty['time'],
        'CE_VOL_@'+nifty['time'],
        'PE_VOL_@'+nifty['time'],
        'CE_LTP_CHG_@'+nifty['time'],
        'PE_LTP_CHG_@'+nifty['time']
    ]
    
    for col in cols:
        dataframe[col] = np.nan
    
    for one in soup.find_all('div',{'class':'opttbldata'})[0].find_all('tr')[2:-1]:
        one = one.find_all('td')
        strike = one[11].text
        if(int(float(strike)) not in list(df['strike_price'])):
            continue
        values = dict()
        values[cols[0]] = one[1].text
        values[cols[1]] = one[2].text
        values[cols[2]] = one[4].text
        values[cols[3]] = one[5].text
        values[cols[4]] = one[21].text
        values[cols[5]] = one[20].text
        values[cols[6]] = one[18].text
        values[cols[7]] = one[17].text
        values[cols[8]] = nifty['nifty']
        values[cols[9]] = one[3].text
        values[cols[10]] = one[19].text
        values[cols[11]] = one[6].text
        values[cols[12]] = one[16].text
        
    
        for key in values:
            values[key] = values[key].replace(" ","")
            values[key] = values[key].replace("\t","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace("\r","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace(",","")
            try: 
                values[key] = float(values[key])
            except:
                values[key] = np.nan
            
            dataframe.loc[int(float(strike)),key] = values[key]

    return dataframe

# %%
def automation(curtime, df):
    
    soup = get_soup(url)
    nifty = get_nifty(soup)
    print(nifty)
    
    if(curtime == nifty['time']):
        print("Failed to add! time:"+curtime)
        return curtime,df
    else:
        cutime = nifty['time']
        
    df=insert_values(soup, nifty, df)
    df.to_csv('data.csv',index=True)
    
    return nifty['time'],df

# %%
#curtime,df = automation(curtime, df)

# %%
while True:
    print("Start")
    curtime,df = automation(curtime, df)
    time.sleep(60*7)
# Out:
# Start
# Soup generation. 200!
# {'nifty': '13007.15', 'time': '09:36:51'}
# Start
# Soup generation. 200!
# {'nifty': '13012.05', 'time': '09:43:21'}
# Start
# Soup generation. 200!
# {'nifty': '13008.90', 'time': '09:51:21'}
# Start
# Soup generation. 200!
# {'nifty': '13029.15', 'time': '09:56:51'}
# Start
# Soup generation. 200!
# {'nifty': '13028.40', 'time': '10:03:51'}
# Start
# Soup generation. 200!
# {'nifty': '13029.55', 'time': '10:11:21'}
# Start
# Soup generation. 200!
# {'nifty': '13040.45', 'time': '10:18:51'}
# Start
# Soup generation. 200!
# {'nifty': '13036.65', 'time': '10:26:21'}
# Start
# Soup generation. 200!
# {'nifty': '13032.50', 'time': '10:33:21'}
# Start
# Soup generation. 200!
# {'nifty': '13053.45', 'time': '10:39:22'}
# Start
# Soup generation. 200!
# {'nifty': '13067.65', 'time': '10:44:22'}
# Start
# Soup generation. 200!
# {'nifty': '13070.05', 'time': '10:52:22'}
# Start
# Soup generation. 200!
# {'nifty': '13068.25', 'time': '10:59:22'}
# Start
# Soup generation. 200!
# {'nifty': '13077.00', 'time': '11:09:22'}
# Start
# Soup generation. 200!
# {'nifty': '13078.10', 'time': '11:15:22'}
# Start
# Soup generation. 200!
# {'nifty': '13078.95', 'time': '11:20:52'}
# Start
# Soup generation. 200!
# {'nifty': '13075.80', 'time': '11:28:53'}
# Start
# Soup generation. 200!
# {'nifty': '13071.60', 'time': '11:39:23'}
# Start
# Soup generation. 200!
# {'nifty': '13074.60', 'time': '11:46:53'}
# Start
# Soup generation. 200!
# {'nifty': '13075.95', 'time': '11:53:53'}
# Start
# Soup generation. 200!
# {'nifty': '13088.95', 'time': '12:00:54'}
# Start
# Soup generation. 200!
# {'nifty': '13075.60', 'time': '12:09:24'}
# Start
# Soup generation. 200!
# {'nifty': '13075.45', 'time': '12:16:24'}
# Start
# Soup generation. 200!
# {'nifty': '13080.50', 'time': '12:22:54'}
# Start
# Soup generation. 200!
# {'nifty': '13054.90', 'time': '12:29:54'}
# Start
# Soup generation. 200!
# {'nifty': '13064.40', 'time': '12:36:24'}
# Start
# Soup generation. 200!
# {'nifty': '13055.55', 'time': '12:42:24'}
# Start
# Soup generation. 200!
# {'nifty': '13059.25', 'time': '12:51:25'}
# Start
# Soup generation. 200!
# {'nifty': '13077.95', 'time': '12:57:25'}
# Start
# Soup generation. 200!
# {'nifty': '13082.25', 'time': '13:03:25'}
# Start
# Soup generation. 200!
# {'nifty': '13090.85', 'time': '13:10:55'}
# Start
# Soup generation. 200!
# {'nifty': '13088.50', 'time': '13:18:55'}
# Start
# Soup generation. 200!
# {'nifty': '13083.15', 'time': '13:25:25'}
# Start
# Soup generation. 200!
# {'nifty': '13078.90', 'time': '13:32:55'}
# Start
# Soup generation. 200!
# {'nifty': '13099.45', 'time': '13:40:56'}
# Start
# Soup generation. 200!
# {'nifty': '13084.00', 'time': '13:47:56'}
# Start
# Soup generation. 200!
# {'nifty': '13091.90', 'time': '13:53:26'}
# Start
# Soup generation. 200!
# {'nifty': '13094.30', 'time': '14:00:26'}
# Start
# Soup generation. 200!
# {'nifty': '13102.80', 'time': '14:06:56'}
# Start
# Soup generation. 200!
# {'nifty': '13118.80', 'time': '14:14:56'}
# Start
# Soup generation. 200!
# {'nifty': '13110.35', 'time': '14:22:26'}
# Start
# Soup generation. 200!
# {'nifty': '13114.85', 'time': '14:29:27'}
# Start
# Soup generation. 200!
# {'nifty': '13110.90', 'time': '14:34:27'}
# Start
# Soup generation. 200!
# {'nifty': '13119.30', 'time': '14:41:57'}
# Start
# Soup generation. 200!
# {'nifty': '13119.00', 'time': '14:50:57'}
# Start
# Soup generation. 200!
# {'nifty': '13113.75', 'time': '14:55:58'}
# Start
# Soup generation. 200!
# {'nifty': '13120.80', 'time': '15:03:27'}
# Start
# Soup generation. 200!
# {'nifty': '13121.90', 'time': '15:10:27'}
# Start
# Soup generation. 200!
# {'nifty': '13093.50', 'time': '15:18:57'}
# Start
# Soup generation. 200!
# {'nifty': '13102.20', 'time': '15:24:58'}
# Start
# Soup generation. 200!
# {'nifty': '13099.00', 'time': '15:29:58'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-458067413f78> in <module>
#       2     print("Start")
#       3     curtime,df = automation(curtime, df)
# ----> 4     time.sleep(60*7)
#
# KeyboardInterrupt:
