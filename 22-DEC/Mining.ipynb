# %%
from nsetools import Nse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import datetime as dt
from datetime import datetime
import pickle5 as pickle
import threading
import os
import json
import time

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp"
curtime = datetime.now().strftime("%H:%M:%S")

#Create dataframe
strikes = [50*i for i in range(220,281)]
df=pd.DataFrame(columns = ['strike_price'], index = strikes)
for i in strikes:
    df.loc[i,'strike_price'] = i

# %%
def get_soup(url):
    response = requests.get(url,headers={'User-Agent':'Mozilla/5.0'})
    if(response.status_code != 200):
        print('Illegal URL')
        return None
    soup = BeautifulSoup(response.text,'lxml')
    print("Soup generation. 200!")
    return soup

# %%
def get_nifty(soup):
    try:
        val1 = soup.find_all('span')[0].text.split()[-1]
        val2 = soup.find_all('span')[1].text.split()[-2]
        return ({'nifty':val1,'time':val2})
    except:
        print("Bad request")
        return None

# %%
def insert_values(soup, nifty, dataframe):
    cols = [
        'CE_OI_@'+nifty['time'],
        'CE_CHOI_@'+nifty['time'],
        'CE_IV_@'+nifty['time'],
        'CE_LTP_@'+nifty['time'],
        'PE_OI_@'+nifty['time'],
        'PE_CHOI_@'+nifty['time'],
        'PE_IV_@'+nifty['time'],
        'PE_LTP_@'+nifty['time'],
        'NIFTY@'+nifty['time'],
        'CE_VOL_@'+nifty['time'],
        'PE_VOL_@'+nifty['time'],
        'CE_LTP_CHG_@'+nifty['time'],
        'PE_LTP_CHG_@'+nifty['time']
    ]
    
    for col in cols:
        dataframe[col] = np.nan
    
    for one in soup.find_all('div',{'class':'opttbldata'})[0].find_all('tr')[2:-1]:
        one = one.find_all('td')
        strike = one[11].text
        if(int(float(strike)) not in list(df['strike_price'])):
            continue
        values = dict()
        values[cols[0]] = one[1].text
        values[cols[1]] = one[2].text
        values[cols[2]] = one[4].text
        values[cols[3]] = one[5].text
        values[cols[4]] = one[21].text
        values[cols[5]] = one[20].text
        values[cols[6]] = one[18].text
        values[cols[7]] = one[17].text
        values[cols[8]] = nifty['nifty']
        values[cols[9]] = one[3].text
        values[cols[10]] = one[19].text
        values[cols[11]] = one[6].text
        values[cols[12]] = one[16].text
        
    
        for key in values:
            values[key] = values[key].replace(" ","")
            values[key] = values[key].replace("\t","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace("\r","")
            values[key] = values[key].replace("\n","")
            values[key] = values[key].replace(",","")
            try: 
                values[key] = float(values[key])
            except:
                values[key] = np.nan
            
            dataframe.loc[int(float(strike)),key] = values[key]

    return dataframe

# %%
def automation(curtime, df):
    
    soup = get_soup(url)
    nifty = get_nifty(soup)
    print(nifty)
    
    if(curtime == nifty['time']):
        print("Failed to add! time:"+curtime)
        return curtime,df
    else:
        cutime = nifty['time']
        
    df=insert_values(soup, nifty, df)
    df.to_csv('data.csv',index=True)
    
    return nifty['time'],df

# %%
#curtime,df = automation(curtime, df)

# %%
while True:
    print("Start")
    curtime,df = automation(curtime, df)
    time.sleep(60*5)
# Out:
# Start
# Soup generation. 200!
# {'nifty': '13195.65', 'time': '09:46:20'}
# Start
# Soup generation. 200!
# {'nifty': '13239.50', 'time': '09:52:20'}
# Start
# Soup generation. 200!
# {'nifty': '13277.60', 'time': '09:55:50'}
# Start
# Soup generation. 200!
# {'nifty': '13263.25', 'time': '10:01:20'}
# Start
# Soup generation. 200!
# {'nifty': '13296.35', 'time': '10:07:21'}
# Start
# Soup generation. 200!
# {'nifty': '13319.65', 'time': '10:11:21'}
# Start
# Soup generation. 200!
# {'nifty': '13305.95', 'time': '10:17:21'}
# Start
# Soup generation. 200!
# {'nifty': '13325.60', 'time': '10:22:21'}
# Start
# Soup generation. 200!
# {'nifty': '13325.05', 'time': '10:26:21'}
# Start
# Soup generation. 200!
# {'nifty': '13304.55', 'time': '10:31:21'}
# Start
# Soup generation. 200!
# {'nifty': '13312.95', 'time': '10:37:21'}
# Start
# Soup generation. 200!
# {'nifty': '13313.45', 'time': '10:41:51'}
# Start
# Soup generation. 200!
# {'nifty': '13280.15', 'time': '10:47:22'}
# Start
# Soup generation. 200!
# {'nifty': '13297.85', 'time': '10:53:22'}
# Start
# Soup generation. 200!
# {'nifty': '13269.35', 'time': '10:56:52'}
# Start
# Soup generation. 200!
# {'nifty': '13287.75', 'time': '11:01:52'}
# Start
# Soup generation. 200!
# {'nifty': '13292.90', 'time': '11:05:52'}
# Start
# Soup generation. 200!
# {'nifty': '13284.75', 'time': '11:11:52'}
# Start
# Soup generation. 200!
# {'nifty': '13244.80', 'time': '11:17:52'}
# Start
# Soup generation. 200!
# {'nifty': '13249.05', 'time': '11:22:52'}
# Start
# Soup generation. 200!
# {'nifty': '13252.40', 'time': '11:26:22'}
# Start
# Soup generation. 200!
# {'nifty': '13217.20', 'time': '11:39:53'}
# Start
# Soup generation. 200!
# {'nifty': '13225.15', 'time': '11:43:23'}
# Start
# Soup generation. 200!
# {'nifty': '13265.85', 'time': '11:48:53'}
# Start
# Soup generation. 200!
# {'nifty': '13257.30', 'time': '11:52:53'}
# Start
# Soup generation. 200!
# {'nifty': '13256.30', 'time': '11:58:23'}
# Start
# Soup generation. 200!
# {'nifty': '13248.45', 'time': '12:04:53'}
# Start
# Soup generation. 200!
# {'nifty': '13251.60', 'time': '12:09:23'}
# Start
# Soup generation. 200!
# {'nifty': '13245.95', 'time': '12:13:23'}
# Start
# Soup generation. 200!
# {'nifty': '13225.45', 'time': '12:18:53'}
# Start
# Soup generation. 200!
# {'nifty': '13324.30', 'time': '13:27:25'}
# Start
# Soup generation. 200!
# {'nifty': '13295.25', 'time': '13:32:55'}
# Start
# Soup generation. 200!
# {'nifty': '13323.35', 'time': '13:37:25'}
# Start
# Soup generation. 200!
# {'nifty': '13360.75', 'time': '13:42:25'}
# Start
# Soup generation. 200!
# {'nifty': '13341.40', 'time': '13:48:56'}
# Start
# Soup generation. 200!
# {'nifty': '13364.20', 'time': '13:53:26'}
# Start
# Soup generation. 200!
# {'nifty': '13356.60', 'time': '13:57:26'}
# Start
# Soup generation. 200!
# {'nifty': '13389.20', 'time': '14:02:56'}
# Start
# Soup generation. 200!
# {'nifty': '13391.85', 'time': '14:08:56'}
# Start
# Soup generation. 200!
# {'nifty': '13412.10', 'time': '14:11:56'}
# Start
# Soup generation. 200!
# {'nifty': '13443.10', 'time': '14:17:56'}
# Start
# Soup generation. 200!
# {'nifty': '13440.10', 'time': '14:23:26'}
# Start
# Soup generation. 200!
# {'nifty': '13422.15', 'time': '14:26:57'}
# Start
# Soup generation. 200!
# {'nifty': '13436.75', 'time': '14:32:57'}
